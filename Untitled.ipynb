# %%
import numpy
from keras.models import Sequential
from keras.layers import Dense
import tensorflow as tf
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import StratifiedKFold, cross_val_score, GridSearchCV

dataset1 = numpy.loadtxt("data/diabetes.csv", skiprows=1, delimiter=",")
print(dataset1.shape)

inputList = dataset1[:, 0:8]
resultList = dataset1[:, 8]
print(inputList.shape)
print(resultList.shape)


def create_default_model(optimizer='adam', init='uniform'):
    m = Sequential()
    m.add(Dense(14, input_dim=8, kernel_initializer=init, activation=tf.nn.relu))
    m.add(Dense(8, activation=tf.nn.relu))
    output_layer = Dense(1, activation=tf.nn.sigmoid)
    m.add(output_layer)
    m.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    m.summary()
    return m


model = KerasClassifier(build_fn=create_default_model, verbose=0)
optimizers = ['sgd', 'rmsprop', 'adam']
inits = ['normal', 'uniform']
epochs = [50, 100, 150]
batches = [5, 10, 15]
parameterGrid = dict(optimizer=optimizers, epochs=epochs, init=inits, batch_size=batches)
grid = GridSearchCV(estimator=model, param_grid=parameterGrid, cv=3)
grid_result = grid.fit(inputList, resultList)
# Out:
# (768, 9)
# (768, 8)
# (768,)
# Model: "sequential_163"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_489 (Dense)            (None, 14)                126
# _________________________________________________________________
# dense_490 (Dense)            (None, 8)                 120
# _________________________________________________________________
# dense_491 (Dense)            (None, 1)                 9
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_164"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_492 (Dense)            (None, 14)                126
# _________________________________________________________________
# dense_493 (Dense)            (None, 8)                 120
# _________________________________________________________________
# dense_494 (Dense)            (None, 1)                 9
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_165"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_495 (Dense)            (None, 14)                126
# _________________________________________________________________
# dense_496 (Dense)            (None, 8)                 120
# _________________________________________________________________
# dense_497 (Dense)            (None, 1)                 9
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_166"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_498 (Dense)            (None, 14)                126
# _________________________________________________________________
# dense_499 (Dense)            (None, 8)                 120
# _________________________________________________________________
# dense_500 (Dense)            (None, 1)                 9
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_167"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_501 (Dense)            (None, 14)                126
# _________________________________________________________________
# dense_502 (Dense)            (None, 8)                 120
# _________________________________________________________________
# dense_503 (Dense)            (None, 1)                 9
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_168"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_504 (Dense)            (None, 14)                126
# _________________________________________________________________
# dense_505 (Dense)            (None, 8)                 120
# _________________________________________________________________
# dense_506 (Dense)            (None, 1)                 9
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_169"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_507 (Dense)            (None, 14)                126
# _________________________________________________________________
# dense_508 (Dense)            (None, 8)                 120
# _________________________________________________________________
# dense_509 (Dense)            (None, 1)                 9
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_170"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_510 (Dense)            (None, 14)                126
# _________________________________________________________________
# dense_511 (Dense)            (None, 8)                 120
# _________________________________________________________________
# dense_512 (Dense)            (None, 1)                 9
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_171"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_513 (Dense)            (None, 14)                126
# _________________________________________________________________
# dense_514 (Dense)            (None, 8)                 120
# _________________________________________________________________
# dense_515 (Dense)            (None, 1)                 9
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_172"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_516 (Dense)            (None, 14)                126
# _________________________________________________________________
# dense_517 (Dense)            (None, 8)                 120
# _________________________________________________________________
# dense_518 (Dense)            (None, 1)                 9
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_173"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_519 (Dense)            (None, 14)                126
# _________________________________________________________________
# dense_520 (Dense)            (None, 8)                 120
# _________________________________________________________________
# dense_521 (Dense)            (None, 1)                 9
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_174"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_522 (Dense)            (None, 14)                126
# _________________________________________________________________
# dense_523 (Dense)            (None, 8)                 120
# _________________________________________________________________
# dense_524 (Dense)            (None, 1)                 9
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_175"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_525 (Dense)            (None, 14)                126
# _________________________________________________________________
# dense_526 (Dense)            (None, 8)                 120
# _________________________________________________________________
# dense_527 (Dense)            (None, 1)                 9
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_176"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_528 (Dense)            (None, 14)                126
# _________________________________________________________________
# dense_529 (Dense)            (None, 8)                 120
# _________________________________________________________________
# dense_530 (Dense)            (None, 1)                 9
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_177"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_531 (Dense)            (None, 14)                126
# _________________________________________________________________
# dense_532 (Dense)            (None, 8)                 120
# _________________________________________________________________
# dense_533 (Dense)            (None, 1)                 9
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_178"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_534 (Dense)            (None, 14)                126
# _________________________________________________________________
# dense_535 (Dense)            (None, 8)                 120
# _________________________________________________________________
# dense_536 (Dense)            (None, 1)                 9
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_179"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_537 (Dense)            (None, 14)                126
# _________________________________________________________________
# dense_538 (Dense)            (None, 8)                 120
# _________________________________________________________________
# dense_539 (Dense)            (None, 1)                 9
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_180"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_540 (Dense)            (None, 14)                126
# _________________________________________________________________
# dense_541 (Dense)            (None, 8)                 120
# _________________________________________________________________
# dense_542 (Dense)            (None, 1)                 9
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_181"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_543 (Dense)            (None, 14)                126
# _________________________________________________________________
# dense_544 (Dense)            (None, 8)                 120
# _________________________________________________________________
# dense_545 (Dense)            (None, 1)                 9
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_182"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_546 (Dense)            (None, 14)                126
# _________________________________________________________________
# dense_547 (Dense)            (None, 8)                 120
# _________________________________________________________________
# dense_548 (Dense)            (None, 1)                 9
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_183"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_549 (Dense)            (None, 14)                126
# _________________________________________________________________
# dense_550 (Dense)            (None, 8)                 120
# _________________________________________________________________
# dense_551 (Dense)            (None, 1)                 9
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_184"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_552 (Dense)            (None, 14)                126
# _________________________________________________________________
# dense_553 (Dense)            (None, 8)                 120
# _________________________________________________________________
# dense_554 (Dense)            (None, 1)                 9
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_185"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_555 (Dense)            (None, 14)                126
# _________________________________________________________________
# dense_556 (Dense)            (None, 8)                 120
# _________________________________________________________________
# dense_557 (Dense)            (None, 1)                 9
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_186"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_558 (Dense)            (None, 14)                126
# _________________________________________________________________
# dense_559 (Dense)            (None, 8)                 120
# _________________________________________________________________
# dense_560 (Dense)            (None, 1)                 9
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_187"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_561 (Dense)            (None, 14)                126
# _________________________________________________________________
# dense_562 (Dense)            (None, 8)                 120
# _________________________________________________________________
# dense_563 (Dense)            (None, 1)                 9
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_188"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_564 (Dense)            (None, 14)                126
# _________________________________________________________________
# dense_565 (Dense)            (None, 8)                 120
# _________________________________________________________________
# dense_566 (Dense)            (None, 1)                 9
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_189"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_567 (Dense)            (None, 14)                126
# _________________________________________________________________
# dense_568 (Dense)            (None, 8)                 120
# _________________________________________________________________
# dense_569 (Dense)            (None, 1)                 9
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_190"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_570 (Dense)            (None, 14)                126
# _________________________________________________________________
# dense_571 (Dense)            (None, 8)                 120
# _________________________________________________________________
# dense_572 (Dense)            (None, 1)                 9
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_191"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_573 (Dense)            (None, 14)                126
# _________________________________________________________________
# dense_574 (Dense)            (None, 8)                 120
# _________________________________________________________________
# dense_575 (Dense)            (None, 1)                 9
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_192"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_576 (Dense)            (None, 14)                126
# _________________________________________________________________
# dense_577 (Dense)            (None, 8)                 120
# _________________________________________________________________
# dense_578 (Dense)            (None, 1)                 9
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_193"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_579 (Dense)            (None, 14)                126
# _________________________________________________________________
# dense_580 (Dense)            (None, 8)                 120
# _________________________________________________________________
# dense_581 (Dense)            (None, 1)                 9
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_194"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_582 (Dense)            (None, 14)                126
# _________________________________________________________________
# dense_583 (Dense)            (None, 8)                 120
# _________________________________________________________________
# dense_584 (Dense)            (None, 1)                 9
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_195"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_585 (Dense)            (None, 14)                126
# _________________________________________________________________
# dense_586 (Dense)            (None, 8)                 120
# _________________________________________________________________
# dense_587 (Dense)            (None, 1)                 9
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_196"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_588 (Dense)            (None, 14)                126
# _________________________________________________________________
# dense_589 (Dense)            (None, 8)                 120
# _________________________________________________________________
# dense_590 (Dense)            (None, 1)                 9
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_197"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_591 (Dense)            (None, 14)                126
# _________________________________________________________________
# dense_592 (Dense)            (None, 8)                 120
# _________________________________________________________________
# dense_593 (Dense)            (None, 1)                 9
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_198"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_594 (Dense)            (None, 14)                126
# _________________________________________________________________
# dense_595 (Dense)            (None, 8)                 120
# _________________________________________________________________
# dense_596 (Dense)            (None, 1)                 9
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_199"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_597 (Dense)            (None, 14)                126
# _________________________________________________________________
# dense_598 (Dense)            (None, 8)                 120
# _________________________________________________________________
# dense_599 (Dense)            (None, 1)                 9
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_200"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_600 (Dense)            (None, 14)                126
# _________________________________________________________________
# dense_601 (Dense)            (None, 8)                 120
# _________________________________________________________________
# dense_602 (Dense)            (None, 1)                 9
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_201"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_603 (Dense)            (None, 14)                126
# _________________________________________________________________
# dense_604 (Dense)            (None, 8)                 120
# _________________________________________________________________
# dense_605 (Dense)            (None, 1)                 9
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_202"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_606 (Dense)            (None, 14)                126
# _________________________________________________________________
# dense_607 (Dense)            (None, 8)                 120
# _________________________________________________________________
# dense_608 (Dense)            (None, 1)                 9
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_203"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_609 (Dense)            (None, 14)                126
# _________________________________________________________________
# dense_610 (Dense)            (None, 8)                 120
# _________________________________________________________________
# dense_611 (Dense)            (None, 1)                 9
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_204"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_612 (Dense)            (None, 14)                126
# _________________________________________________________________
# dense_613 (Dense)            (None, 8)                 120
# _________________________________________________________________
# dense_614 (Dense)            (None, 1)                 9
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_205"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_615 (Dense)            (None, 14)                126
# _________________________________________________________________
# dense_616 (Dense)            (None, 8)                 120
# _________________________________________________________________
# dense_617 (Dense)            (None, 1)                 9
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_206"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_618 (Dense)            (None, 14)                126
# _________________________________________________________________
# dense_619 (Dense)            (None, 8)                 120
# _________________________________________________________________
# dense_620 (Dense)            (None, 1)                 9
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_207"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_621 (Dense)            (None, 14)                126
# _________________________________________________________________
# dense_622 (Dense)            (None, 8)                 120
# _________________________________________________________________
# dense_623 (Dense)            (None, 1)                 9
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_208"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_624 (Dense)            (None, 14)                126
# _________________________________________________________________
# dense_625 (Dense)            (None, 8)                 120
# _________________________________________________________________
# dense_626 (Dense)            (None, 1)                 9
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_209"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_627 (Dense)            (None, 14)                126
# _________________________________________________________________
# dense_628 (Dense)            (None, 8)                 120
# _________________________________________________________________
# dense_629 (Dense)            (None, 1)                 9
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_210"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_630 (Dense)            (None, 14)                126
# _________________________________________________________________
# dense_631 (Dense)            (None, 8)                 120
# _________________________________________________________________
# dense_632 (Dense)            (None, 1)                 9
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_211"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_633 (Dense)            (None, 14)                126
# _________________________________________________________________
# dense_634 (Dense)            (None, 8)                 120
# _________________________________________________________________
# dense_635 (Dense)            (None, 1)                 9
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_212"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_636 (Dense)            (None, 14)                126
# _________________________________________________________________
# dense_637 (Dense)            (None, 8)                 120
# _________________________________________________________________
# dense_638 (Dense)            (None, 1)                 9
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_213"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_639 (Dense)            (None, 14)                126
# _________________________________________________________________
# dense_640 (Dense)            (None, 8)                 120
# _________________________________________________________________
# dense_641 (Dense)            (None, 1)                 9
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_214"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_642 (Dense)            (None, 14)                126
# _________________________________________________________________
# dense_643 (Dense)            (None, 8)                 120
# _________________________________________________________________
# dense_644 (Dense)            (None, 1)                 9
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_215"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_645 (Dense)            (None, 14)                126
# _________________________________________________________________
# dense_646 (Dense)            (None, 8)                 120
# _________________________________________________________________
# dense_647 (Dense)            (None, 1)                 9
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_216"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_648 (Dense)            (None, 14)                126
# _________________________________________________________________
# dense_649 (Dense)            (None, 8)                 120
# _________________________________________________________________
# dense_650 (Dense)            (None, 1)                 9
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_217"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_651 (Dense)            (None, 14)                126
# _________________________________________________________________
# dense_652 (Dense)            (None, 8)                 120
# _________________________________________________________________
# dense_653 (Dense)            (None, 1)                 9
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_218"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_654 (Dense)            (None, 14)                126
# _________________________________________________________________
# dense_655 (Dense)            (None, 8)                 120
# _________________________________________________________________
# dense_656 (Dense)            (None, 1)                 9
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_219"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_657 (Dense)            (None, 14)                126
# _________________________________________________________________
# dense_658 (Dense)            (None, 8)                 120
# _________________________________________________________________
# dense_659 (Dense)            (None, 1)                 9
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_220"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_660 (Dense)            (None, 14)                126
# _________________________________________________________________
# dense_661 (Dense)            (None, 8)                 120
# _________________________________________________________________
# dense_662 (Dense)            (None, 1)                 9
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_221"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_663 (Dense)            (None, 14)                126
# _________________________________________________________________
# dense_664 (Dense)            (None, 8)                 120
# _________________________________________________________________
# dense_665 (Dense)            (None, 1)                 9
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_222"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_666 (Dense)            (None, 14)                126
# _________________________________________________________________
# dense_667 (Dense)            (None, 8)                 120
# _________________________________________________________________
# dense_668 (Dense)            (None, 1)                 9
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_223"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_669 (Dense)            (None, 14)                126
# _________________________________________________________________
# dense_670 (Dense)            (None, 8)                 120
# _________________________________________________________________
# dense_671 (Dense)            (None, 1)                 9
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_224"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_672 (Dense)            (None, 14)                126
# _________________________________________________________________
# dense_673 (Dense)            (None, 8)                 120
# _________________________________________________________________
# dense_674 (Dense)            (None, 1)                 9
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_225"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_675 (Dense)            (None, 14)                126
# _________________________________________________________________
# dense_676 (Dense)            (None, 8)                 120
# _________________________________________________________________
# dense_677 (Dense)            (None, 1)                 9
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_226"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_678 (Dense)            (None, 14)                126
# _________________________________________________________________
# dense_679 (Dense)            (None, 8)                 120
# _________________________________________________________________
# dense_680 (Dense)            (None, 1)                 9
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_227"
# _________________________________________________________________
# ...
# dense_914 (Dense)            (None, 1)                 9
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_305"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_915 (Dense)            (None, 14)                126
# _________________________________________________________________
# dense_916 (Dense)            (None, 8)                 120
# _________________________________________________________________
# dense_917 (Dense)            (None, 1)                 9
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_306"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_918 (Dense)            (None, 14)                126
# _________________________________________________________________
# dense_919 (Dense)            (None, 8)                 120
# _________________________________________________________________
# dense_920 (Dense)            (None, 1)                 9
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_307"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_921 (Dense)            (None, 14)                126
# _________________________________________________________________
# dense_922 (Dense)            (None, 8)                 120
# _________________________________________________________________
# dense_923 (Dense)            (None, 1)                 9
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_308"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_924 (Dense)            (None, 14)                126
# _________________________________________________________________
# dense_925 (Dense)            (None, 8)                 120
# _________________________________________________________________
# dense_926 (Dense)            (None, 1)                 9
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_309"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_927 (Dense)            (None, 14)                126
# _________________________________________________________________
# dense_928 (Dense)            (None, 8)                 120
# _________________________________________________________________
# dense_929 (Dense)            (None, 1)                 9
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_310"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_930 (Dense)            (None, 14)                126
# _________________________________________________________________
# dense_931 (Dense)            (None, 8)                 120
# _________________________________________________________________
# dense_932 (Dense)            (None, 1)                 9
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_311"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_933 (Dense)            (None, 14)                126
# _________________________________________________________________
# dense_934 (Dense)            (None, 8)                 120
# _________________________________________________________________
# dense_935 (Dense)            (None, 1)                 9
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_312"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_936 (Dense)            (None, 14)                126
# _________________________________________________________________
# dense_937 (Dense)            (None, 8)                 120
# _________________________________________________________________
# dense_938 (Dense)            (None, 1)                 9
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_313"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_939 (Dense)            (None, 14)                126
# _________________________________________________________________
# dense_940 (Dense)            (None, 8)                 120
# _________________________________________________________________
# dense_941 (Dense)            (None, 1)                 9
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_314"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_942 (Dense)            (None, 14)                126
# _________________________________________________________________
# dense_943 (Dense)            (None, 8)                 120
# _________________________________________________________________
# dense_944 (Dense)            (None, 1)                 9
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_315"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_945 (Dense)            (None, 14)                126
# _________________________________________________________________
# dense_946 (Dense)            (None, 8)                 120
# _________________________________________________________________
# dense_947 (Dense)            (None, 1)                 9
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_316"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_948 (Dense)            (None, 14)                126
# _________________________________________________________________
# dense_949 (Dense)            (None, 8)                 120
# _________________________________________________________________
# dense_950 (Dense)            (None, 1)                 9
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_317"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_951 (Dense)            (None, 14)                126
# _________________________________________________________________
# dense_952 (Dense)            (None, 8)                 120
# _________________________________________________________________
# dense_953 (Dense)            (None, 1)                 9
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_318"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_954 (Dense)            (None, 14)                126
# _________________________________________________________________
# dense_955 (Dense)            (None, 8)                 120
# _________________________________________________________________
# dense_956 (Dense)            (None, 1)                 9
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_319"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_957 (Dense)            (None, 14)                126
# _________________________________________________________________
# dense_958 (Dense)            (None, 8)                 120
# _________________________________________________________________
# dense_959 (Dense)            (None, 1)                 9
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_320"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_960 (Dense)            (None, 14)                126
# _________________________________________________________________
# dense_961 (Dense)            (None, 8)                 120
# _________________________________________________________________
# dense_962 (Dense)            (None, 1)                 9
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_321"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_963 (Dense)            (None, 14)                126
# _________________________________________________________________
# dense_964 (Dense)            (None, 8)                 120
# _________________________________________________________________
# dense_965 (Dense)            (None, 1)                 9
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_322"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_966 (Dense)            (None, 14)                126
# _________________________________________________________________
# dense_967 (Dense)            (None, 8)                 120
# _________________________________________________________________
# dense_968 (Dense)            (None, 1)                 9
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_323"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_969 (Dense)            (None, 14)                126
# _________________________________________________________________
# dense_970 (Dense)            (None, 8)                 120
# _________________________________________________________________
# dense_971 (Dense)            (None, 1)                 9
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_324"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_972 (Dense)            (None, 14)                126
# _________________________________________________________________
# dense_973 (Dense)            (None, 8)                 120
# _________________________________________________________________
# dense_974 (Dense)            (None, 1)                 9
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_325"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_975 (Dense)            (None, 14)                126
# _________________________________________________________________
# dense_976 (Dense)            (None, 8)                 120
# _________________________________________________________________
# dense_977 (Dense)            (None, 1)                 9
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________

# %%
type(grid_result)
# Out:
# sklearn.model_selection._search.GridSearchCV

# %%
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, std, param in zip(means, stds, params):
    print(f"{param}==>mean={mean:.3f}, std={std:.3f}")
# Out:
# {'batch_size': 5, 'epochs': 50, 'init': 'normal', 'optimizer': 'sgd'}==>mean=0.659, std=0.014
# {'batch_size': 5, 'epochs': 50, 'init': 'normal', 'optimizer': 'rmsprop'}==>mean=0.699, std=0.018
# {'batch_size': 5, 'epochs': 50, 'init': 'normal', 'optimizer': 'adam'}==>mean=0.704, std=0.048
# {'batch_size': 5, 'epochs': 50, 'init': 'uniform', 'optimizer': 'sgd'}==>mean=0.651, std=0.025
# {'batch_size': 5, 'epochs': 50, 'init': 'uniform', 'optimizer': 'rmsprop'}==>mean=0.686, std=0.037
# {'batch_size': 5, 'epochs': 50, 'init': 'uniform', 'optimizer': 'adam'}==>mean=0.719, std=0.006
# {'batch_size': 5, 'epochs': 100, 'init': 'normal', 'optimizer': 'sgd'}==>mean=0.664, std=0.034
# {'batch_size': 5, 'epochs': 100, 'init': 'normal', 'optimizer': 'rmsprop'}==>mean=0.734, std=0.017
# {'batch_size': 5, 'epochs': 100, 'init': 'normal', 'optimizer': 'adam'}==>mean=0.724, std=0.023
# {'batch_size': 5, 'epochs': 100, 'init': 'uniform', 'optimizer': 'sgd'}==>mean=0.663, std=0.010
# {'batch_size': 5, 'epochs': 100, 'init': 'uniform', 'optimizer': 'rmsprop'}==>mean=0.723, std=0.013
# {'batch_size': 5, 'epochs': 100, 'init': 'uniform', 'optimizer': 'adam'}==>mean=0.720, std=0.013
# {'batch_size': 5, 'epochs': 150, 'init': 'normal', 'optimizer': 'sgd'}==>mean=0.676, std=0.051
# {'batch_size': 5, 'epochs': 150, 'init': 'normal', 'optimizer': 'rmsprop'}==>mean=0.742, std=0.027
# {'batch_size': 5, 'epochs': 150, 'init': 'normal', 'optimizer': 'adam'}==>mean=0.708, std=0.026
# {'batch_size': 5, 'epochs': 150, 'init': 'uniform', 'optimizer': 'sgd'}==>mean=0.651, std=0.025
# {'batch_size': 5, 'epochs': 150, 'init': 'uniform', 'optimizer': 'rmsprop'}==>mean=0.716, std=0.014
# {'batch_size': 5, 'epochs': 150, 'init': 'uniform', 'optimizer': 'adam'}==>mean=0.737, std=0.023
# {'batch_size': 10, 'epochs': 50, 'init': 'normal', 'optimizer': 'sgd'}==>mean=0.658, std=0.016
# {'batch_size': 10, 'epochs': 50, 'init': 'normal', 'optimizer': 'rmsprop'}==>mean=0.651, std=0.024
# {'batch_size': 10, 'epochs': 50, 'init': 'normal', 'optimizer': 'adam'}==>mean=0.703, std=0.008
# {'batch_size': 10, 'epochs': 50, 'init': 'uniform', 'optimizer': 'sgd'}==>mean=0.651, std=0.025
# {'batch_size': 10, 'epochs': 50, 'init': 'uniform', 'optimizer': 'rmsprop'}==>mean=0.659, std=0.027
# {'batch_size': 10, 'epochs': 50, 'init': 'uniform', 'optimizer': 'adam'}==>mean=0.693, std=0.011
# {'batch_size': 10, 'epochs': 100, 'init': 'normal', 'optimizer': 'sgd'}==>mean=0.651, std=0.025
# {'batch_size': 10, 'epochs': 100, 'init': 'normal', 'optimizer': 'rmsprop'}==>mean=0.699, std=0.022
# {'batch_size': 10, 'epochs': 100, 'init': 'normal', 'optimizer': 'adam'}==>mean=0.732, std=0.018
# {'batch_size': 10, 'epochs': 100, 'init': 'uniform', 'optimizer': 'sgd'}==>mean=0.652, std=0.032
# {'batch_size': 10, 'epochs': 100, 'init': 'uniform', 'optimizer': 'rmsprop'}==>mean=0.716, std=0.013
# {'batch_size': 10, 'epochs': 100, 'init': 'uniform', 'optimizer': 'adam'}==>mean=0.716, std=0.010
# {'batch_size': 10, 'epochs': 150, 'init': 'normal', 'optimizer': 'sgd'}==>mean=0.681, std=0.027
# {'batch_size': 10, 'epochs': 150, 'init': 'normal', 'optimizer': 'rmsprop'}==>mean=0.686, std=0.025
# {'batch_size': 10, 'epochs': 150, 'init': 'normal', 'optimizer': 'adam'}==>mean=0.728, std=0.019
# {'batch_size': 10, 'epochs': 150, 'init': 'uniform', 'optimizer': 'sgd'}==>mean=0.658, std=0.016
# {'batch_size': 10, 'epochs': 150, 'init': 'uniform', 'optimizer': 'rmsprop'}==>mean=0.719, std=0.032
# {'batch_size': 10, 'epochs': 150, 'init': 'uniform', 'optimizer': 'adam'}==>mean=0.742, std=0.028
# {'batch_size': 15, 'epochs': 50, 'init': 'normal', 'optimizer': 'sgd'}==>mean=0.659, std=0.034
# {'batch_size': 15, 'epochs': 50, 'init': 'normal', 'optimizer': 'rmsprop'}==>mean=0.681, std=0.033
# {'batch_size': 15, 'epochs': 50, 'init': 'normal', 'optimizer': 'adam'}==>mean=0.699, std=0.019
# {'batch_size': 15, 'epochs': 50, 'init': 'uniform', 'optimizer': 'sgd'}==>mean=0.665, std=0.034
# {'batch_size': 15, 'epochs': 50, 'init': 'uniform', 'optimizer': 'rmsprop'}==>mean=0.608, std=0.103
# {'batch_size': 15, 'epochs': 50, 'init': 'uniform', 'optimizer': 'adam'}==>mean=0.712, std=0.013
# {'batch_size': 15, 'epochs': 100, 'init': 'normal', 'optimizer': 'sgd'}==>mean=0.659, std=0.030
# {'batch_size': 15, 'epochs': 100, 'init': 'normal', 'optimizer': 'rmsprop'}==>mean=0.695, std=0.011
# {'batch_size': 15, 'epochs': 100, 'init': 'normal', 'optimizer': 'adam'}==>mean=0.719, std=0.022
# {'batch_size': 15, 'epochs': 100, 'init': 'uniform', 'optimizer': 'sgd'}==>mean=0.638, std=0.059
# {'batch_size': 15, 'epochs': 100, 'init': 'uniform', 'optimizer': 'rmsprop'}==>mean=0.725, std=0.024
# {'batch_size': 15, 'epochs': 100, 'init': 'uniform', 'optimizer': 'adam'}==>mean=0.710, std=0.011
# {'batch_size': 15, 'epochs': 150, 'init': 'normal', 'optimizer': 'sgd'}==>mean=0.663, std=0.010
# {'batch_size': 15, 'epochs': 150, 'init': 'normal', 'optimizer': 'rmsprop'}==>mean=0.698, std=0.044
# {'batch_size': 15, 'epochs': 150, 'init': 'normal', 'optimizer': 'adam'}==>mean=0.717, std=0.019
# {'batch_size': 15, 'epochs': 150, 'init': 'uniform', 'optimizer': 'sgd'}==>mean=0.665, std=0.007
# {'batch_size': 15, 'epochs': 150, 'init': 'uniform', 'optimizer': 'rmsprop'}==>mean=0.719, std=0.023
# {'batch_size': 15, 'epochs': 150, 'init': 'uniform', 'optimizer': 'adam'}==>mean=0.732, std=0.024

# %%
f"Best param={grid_result.best_params_}, score={grid_result.best_score_}"
# Out:
# "Best param={'batch_size': 5, 'epochs': 150, 'init': 'normal', 'optimizer': 'rmsprop'}, score=0.7421875"
